# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\git tutorial\project-1-MLOP\notebook\student_career_success_dataset.csv")
df.head()
# Out:
#   Student_ID  Age  Gender University_Year                   Major  \
# 0   ST000001   22    Male       Sophomore        Computer Science
# 1   ST000002   20  Female        Freshman        Computer Science
# 2   ST000003   23    Male          Senior  Information Technology
# 3   ST000004   23  Female          Senior  Information Technology
# 4   ST000005   23  Female          Senior    Software Engineering
#
#    Attendance_Percentage  Study_Hours_Per_Week  CGPA Academic_Performance  \
# 0                     86                    21  3.28                 Good
# 1                     64                    18  2.53                 Poor
# 2                     75                    19  2.83              Average
# 3                     80                    19  2.80              Average
# 4                     73                    19  2.93              Average
#
#    Programming_Skill  ...  Teamwork  Problem_Solving  English_Proficiency  \
# ...

# %%
data=df.to_dict(orient='records')
#data

# %%
DB_NAME = "student_career_success"
COLLECTION_NAME = "students"
CONNECTION_URI = "mongodb+srv://agrim23agarwal_db_user:wZ5Nonl80PdND42j@cluster1.cfpknqr.mongodb.net/?appName=Cluster1"

# %%
pip install pymongo
# Out:
# ...
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 3.4 MB/s  0:00:00
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
# ...

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URI)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# %%
records = collection.insert_many(data)

# %%
print(type(records))
# Out:
# <class 'pymongo.results.InsertManyResult'>
